# %%
import pygame
import random
pygame.init()
pygame.font.init()
size = (800, 550)
screen = pygame.display.set_mode(size)
myfont=pygame.font.SysFont('Arial Unicode MS',40)
myfont2=pygame.font.SysFont('Fixedsys',100)
pygame.display.set_caption("Pacman")
done = False
black=(0,0,0)
red=(225,0,0)
blue=(0,0,225)
yellow=(250,237,80)
purple=(231,14,231)
green=(0,225,0)
white=(255,255,255)
grey=(154,155,147)
D_yellow=(210,205,6)
score=0
out=False
win=False
pac_x=526
pac_y=25
mon_x=25
mon_y=25
pac_speed_ver=0
pac_speed_hor=0
pacman_pace=3
monster_pace=3
if out==False or win==False:
    mon_speed_ver=monster_pace
    mon_speed_hor=monster_pace

a=False

################################################33
food1 = True
food2 = True
food3 = True
food4 = True
food5 = True
food6 = True
food7 = True
food8 = True
food9 = True
food10 = True
food11 = True
food12 = True
food13 = True
food14 = True
food15 = True
food16 = True
food17 = True
food18 = True
food19 = True
food20 = True
food21 = True
food22 = True
food23 = True
food24 = True
food25 = True
food26 = True
food27 = True
food28 = True
food29 = True
food30 = True
food31 = True
food32 = True
food33 = True
food34 = True
food35 = True
food36 = True
food37 = True
food38 = True
food39 = True
food40 = True
food41 = True
food42 = True
food43 = True
food44 = True
food45 = True
food46 = True
food47 = True
food48 = True
food49 = True
food50 = True
food51 = True
food52 = True
food53 = True
food54 = True
food55 = True
food56 = True
food57 = True
food58 = True
food59 = True
food60 = True
food61 = True
food62 = True
food63 = True
food64 = True
food65 = True
food66 = True
food67 = True
food68 = True
food69 = True
food70 = True
food71 = True
food72 = True
f1=True
f2 =True
f3 =True
f4 =True
f5 =True
f6 =True
f7 =True
f8 =True
f9 =True
f10 =True
f11 =True
f12 =True
f13 =True
f14 =True
f15 =True
f16 =True
f17 =True
f18 =True
f19 =True
f20 =True
f21 =True
f22 =True
f23 =True
f24 =True
f25 =True
f26 =True
f27 =True
f28 =True
f29 =True
f30 =True
f31 =True
f32 =True
f33 =True
f34 =True
f35 =True
f36 =True
f37 =True
f38 =True
f39 =True
f40 =True
f41 =True
f42 =True
f43 =True
f44 =True
f45 =True
f46 =True
f47 =True
f48 =True
f49 =True
f50 =True
f51 =True
f52 =True
f53 =True
f54 =True
f55 =True
f56 =True
f57 =True
f58 =True
f59 =True
f60 =True
f61 =True
f62 =True
f63 =True
f64 =True
f65 =True
f66 =True
f67 =True
f68 =True
f69 =True
f70 =True
f71 =True
f72 =True
###################################################3333
x=[25,277,526,775]
y=[25,172,328,475]

mon1=[25,277,526,775,25,277,526,775,25,277,526,775,25,277,526,775]
mon2=[25,25,25,25,172,172,172,172,328,328,328,328,475,475,475,475]

x_way=[]
for i in range(25,776):
    x_way.append(i)
y_way=[]
for j in range(25,476):
    y_way.append(j)
    
textsurface3=myfont2.render('GAME OVER!',False,(255,0,0))

clock = pygame.time.Clock()
#if food1==False and a=1:
#    score+=1
#    a+=1
while not done:
    bounty=72-score
    textsurface=myfont.render(str(score),False,(0,0,0))
    textsurface2=myfont.render('Score:',False,(0,0,0))
    textsurface5=myfont.render('Remaining Bounty:',False,(0,0,0))
    textsurface6=myfont.render(str(bounty),False,(0,0,0))
    textsurface4=myfont2.render('YOU WIN!',False,(255,0,0))
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            done = True
        if event.type == pygame.KEYDOWN:
            if event.key == pygame.K_UP:
                if out==False and win==False:
                    pac_speed_ver=-pacman_pace
                #pac_speed_hor=0
            if event.key == pygame.K_DOWN:
                if out==False and win==False:
                    pac_speed_ver=pacman_pace
                #pac_speed_hor=0
            if event.key == pygame.K_LEFT:
                if out==False and win==False:
                    pac_speed_hor=-pacman_pace
                #pac_speed_ver=0
            if event.key == pygame.K_RIGHT:
                if out==False and win==False:
                    pac_speed_hor=pacman_pace
                #pac_speed_ver=0
        
        elif event.type == pygame.KEYUP:
            if event.key == pygame.K_UP:
                pac_speed_ver=0
            if event.key == pygame.K_DOWN:
                pac_speed_ver=0
            if event.key == pygame.K_RIGHT:
                pac_speed_hor=0
            if event.key == pygame.K_LEFT:
                pac_speed_hor=0
        
            
    screen.fill(black)
    pygame.draw.rect(screen,(grey),(0,500,800,50))
    screen.blit(textsurface,(100,510))
    screen.blit(textsurface2,(10,510))
    screen.blit(textsurface5,(480,510))
    screen.blit(textsurface6,(750,510))
    if out==True or win==True:
        pac_speed_ver=0
        pac_speed_hor=0
        mon_speed_ver=0
        mon_speed_hor=0
    if food1 ==True and f1==True:
        pygame.draw.circle(screen,yellow,( 70 , 25 ),5)
    if food2 ==True:
        pygame.draw.circle(screen,yellow,( 140 , 25 ),5)
    if food3 ==True:
        pygame.draw.circle(screen,yellow,( 210 , 25 ),5)
    if food4 ==True:
        pygame.draw.circle(screen,yellow,( 280 , 25 ),5)
    if food5 ==True:
        pygame.draw.circle(screen,yellow,( 350 , 25 ),5)
    if food6 ==True:
        pygame.draw.circle(screen,yellow,( 420 , 25 ),5)
    if food7 ==True:
        pygame.draw.circle(screen,yellow,( 490 , 25 ),5)
    if food8 ==True:
        pygame.draw.circle(screen,yellow,( 560 , 25 ),5)
    if food9 ==True:
        pygame.draw.circle(screen,yellow,( 630 , 25 ),5)
    if food10 ==True:
        pygame.draw.circle(screen,yellow,( 700 , 25 ),5)
    if food11 ==True:
        pygame.draw.circle(screen,yellow,( 770 , 25 ),5)
    if food12 ==True:
        pygame.draw.circle(screen,yellow,( 70 , 172 ),5)
    if food13 ==True:
        pygame.draw.circle(screen,yellow,( 140 , 172 ),5)
    if food14 ==True:
        pygame.draw.circle(screen,yellow,( 210 , 172 ),5)
    if food15 ==True:
        pygame.draw.circle(screen,yellow,( 280 , 172 ),5)
    if food16 ==True:
        pygame.draw.circle(screen,yellow,( 350 , 172 ),5)
    if food17 ==True:
        pygame.draw.circle(screen,yellow,( 420 , 172 ),5)
    if food18 ==True:
        pygame.draw.circle(screen,yellow,( 490 , 172 ),5)
    if food19 ==True:
        pygame.draw.circle(screen,yellow,( 560 , 172 ),5)
    if food20 ==True:
        pygame.draw.circle(screen,yellow,( 630 , 172 ),5)
    if food21 ==True:
        pygame.draw.circle(screen,yellow,( 700 , 172 ),5)
    if food22 ==True:
        pygame.draw.circle(screen,yellow,( 770 , 172 ),5)
    if food23 ==True:
        pygame.draw.circle(screen,yellow,( 70 , 328 ),5)
    if food24 ==True:
        pygame.draw.circle(screen,yellow,( 140 , 328 ),5)
    if food25 ==True:
        pygame.draw.circle(screen,yellow,( 210 , 328 ),5)
    if food26 ==True:
        pygame.draw.circle(screen,yellow,( 280 , 328 ),5)
    if food27 ==True:
        pygame.draw.circle(screen,yellow,( 350 , 328 ),5)
    if food28 ==True:
        pygame.draw.circle(screen,yellow,( 420 , 328 ),5)
    if food29 ==True:
        pygame.draw.circle(screen,yellow,( 490 , 328 ),5)
    if food30 ==True:
        pygame.draw.circle(screen,yellow,( 560 , 328 ),5)
    if food31 ==True:
        pygame.draw.circle(screen,yellow,( 630 , 328 ),5)
    if food32 ==True:
        pygame.draw.circle(screen,yellow,( 700 , 328 ),5)
    if food33 ==True:
        pygame.draw.circle(screen,yellow,( 770 , 328 ),5)
    if food34 ==True:
        pygame.draw.circle(screen,yellow,( 70 , 475 ),5)
    if food35 ==True:
        pygame.draw.circle(screen,yellow,( 140 , 475 ),5)
    if food36 ==True:
        pygame.draw.circle(screen,yellow,( 210 , 475 ),5)
    if food37 ==True:
        pygame.draw.circle(screen,yellow,( 280 , 475 ),5)
    if food38 ==True:
        pygame.draw.circle(screen,yellow,( 350 , 475 ),5)
    if food39 ==True:
        pygame.draw.circle(screen,yellow,( 420 , 475 ),5)
    if food40 ==True:
        pygame.draw.circle(screen,yellow,( 490 , 475 ),5)
    if food41 ==True:
        pygame.draw.circle(screen,yellow,( 560 , 475 ),5)
    if food42 ==True:
        pygame.draw.circle(screen,yellow,( 630 , 475 ),5)
    if food43 ==True:
        pygame.draw.circle(screen,yellow,( 700 , 475 ),5)
    if food44 ==True:
        pygame.draw.circle(screen,yellow,( 770 , 475 ),5)
    if food45 ==True:
        pygame.draw.circle(screen,yellow,( 25 , 70 ),5)
    if food45 ==True:
        pygame.draw.circle(screen,yellow,( 25 , 70 ),5)
    if food46 ==True:
        pygame.draw.circle(screen,yellow,( 25 , 140 ),5)
    if food47 ==True:
        pygame.draw.circle(screen,yellow,( 25 , 210 ),5)
    if food48 ==True:
        pygame.draw.circle(screen,yellow,( 25 , 280 ),5)
    if food49 ==True:
        pygame.draw.circle(screen,yellow,( 25 , 350 ),5)
    if food50 ==True:
        pygame.draw.circle(screen,yellow,( 25 , 420 ),5)
    if food51 ==True:
        pygame.draw.circle(screen,yellow,( 25 , 490 ),5)
    if food52 ==True:
        pygame.draw.circle(screen,yellow,( 277 , 70 ),5)
    if food53 ==True:
        pygame.draw.circle(screen,yellow,( 277 , 140 ),5)
    if food54 ==True:
        pygame.draw.circle(screen,yellow,( 277 , 210 ),5)
    if food55 ==True:
        pygame.draw.circle(screen,yellow,( 277 , 280 ),5)
    if food56 ==True:
        pygame.draw.circle(screen,yellow,( 277 , 350 ),5)
    if food57 ==True:
        pygame.draw.circle(screen,yellow,( 277 , 420 ),5)
    if food58 ==True:
        pygame.draw.circle(screen,yellow,( 277 , 490 ),5)
    if food59 ==True:
        pygame.draw.circle(screen,yellow,( 526 , 70 ),5)
    if food60 ==True:
        pygame.draw.circle(screen,yellow,( 526 , 140 ),5)
    if food61 ==True:
        pygame.draw.circle(screen,yellow,( 526 , 210 ),5)
    if food62 ==True:
        pygame.draw.circle(screen,yellow,( 526 , 280 ),5)
    if food63 ==True:
        pygame.draw.circle(screen,yellow,( 526 , 350 ),5)
    if food64 ==True:
        pygame.draw.circle(screen,yellow,( 526 , 420 ),5)
    if food65 ==True:
        pygame.draw.circle(screen,yellow,( 526 , 490 ),5)
    if food66 ==True:
        pygame.draw.circle(screen,yellow,( 775 , 70 ),5)
    if food67 ==True:
        pygame.draw.circle(screen,yellow,( 775 , 140 ),5)
    if food68 ==True:
        pygame.draw.circle(screen,yellow,( 775 , 210 ),5)
    if food69 ==True:
        pygame.draw.circle(screen,yellow,( 775 , 280 ),5)
    if food70 ==True:
        pygame.draw.circle(screen,yellow,( 775 , 350 ),5)
    if food71 ==True:
        pygame.draw.circle(screen,yellow,( 775 , 420 ),5)
    if food72 ==True:
        pygame.draw.circle(screen,yellow,( 775 , 490 ),5)
##########################################################################################################

####################################################################################################33
    #if out==False:
    pygame.draw.circle(screen,D_yellow,(pac_x,pac_y),20)
    pygame.draw.circle(screen,purple,(mon_x,mon_y),18,4)
    pygame.draw.rect(screen,(blue),(50,50,200,100),4) #left Top L
    pygame.draw.rect(screen,(blue),(300,50,200,100),4)#left Top L
    pygame.draw.rect(screen,(blue),(550,50,200,100),4)
    
    pygame.draw.rect(screen,(blue),(50,200,200,100),4)
    pygame.draw.rect(screen,(blue),(300,200,200,100),4)
    pygame.draw.rect(screen,(blue),(550,200,200,100),4)
    
    pygame.draw.rect(screen,(blue),(50,350,200,100),4)
    pygame.draw.rect(screen,(blue),(300,350,200,100),4)
    pygame.draw.rect(screen,(blue),(550,350,200,100),4)
    
    pygame.draw.rect(screen,(red),(0,0,798,498),6)
    
    #pygame.draw.rect(screen,(purple),(0,500,800,50))
##############################################################################################################   
    if pac_x in x:
        if pac_y in y_way:
            if pac_y<=475 and pac_y>=25:
                pac_y+=pac_speed_ver
                if pac_y<=25:
                    pac_y=25
                if pac_y>=475:
                    pac_y=475
            
    if pac_y in y:
        if pac_x in x_way:
            if pac_x<=775 and pac_x>=25:
                pac_x+=pac_speed_hor
                if pac_x<=25:
                    pac_x=25
                if pac_x>=775:
                    pac_x=775
###########################################################################################################
 
    if mon_x in x:
        if mon_y in y_way:
            if mon_y<=475 and mon_y>=25:
                mon_y+=mon_speed_ver
                if mon_y<=25:
                    mon_y=25
                if mon_y>=475:
                    mon_y=475
            
    if mon_y in y:
        if mon_x in x_way:
            if mon_x<=775 and mon_x>=25:
                mon_x+=mon_speed_hor
                if mon_x<=25:
                    mon_x=25
                if mon_x>=775:
                    mon_x=775  
                    
    if mon_x==775 and mon_y==475 :
        kk=random.randint(0,15)
        mon_x=mon1[kk]
        mon_y=mon2[kk]
    if ((((pac_x- mon_x )**2)+((pac_y- mon_y )**2))**0.5)<38:
        out=True
    if out==True:    
        screen.blit(textsurface3,(200,220))
###########################################################################################################
    if ((((pac_x- 70 )**2)+((pac_y- 25 )**2))**0.5)<25:
        food1 =False
        if food1==False and f1==True:
            score+=1
            f1=False
    if ((((pac_x- 140 )**2)+((pac_y- 25 )**2))**0.5)<25:
        food2 =False
        if food2==False and f2==True:
            score+=1
            f2=False
    if ((((pac_x- 210 )**2)+((pac_y- 25 )**2))**0.5)<25:
        food3 =False
        if food3==False and f3==True:
            score+=1
            f3=False
    if ((((pac_x- 280 )**2)+((pac_y- 25 )**2))**0.5)<25:
        food4 =False
        if food4==False and f4==True:
            score+=1
            f4=False
    if ((((pac_x- 350 )**2)+((pac_y- 25 )**2))**0.5)<25:
        food5 =False
        if food5==False and f5==True:
            score+=1
            f5=False
    if ((((pac_x- 420 )**2)+((pac_y- 25 )**2))**0.5)<25:
        food6 =False
        if food6==False and f6==True:
            score+=1
            f6=False
    if ((((pac_x- 490 )**2)+((pac_y- 25 )**2))**0.5)<25:
        food7 =False
        if food7==False and f7==True:
            score+=1
            f7=False
    if ((((pac_x- 560 )**2)+((pac_y- 25 )**2))**0.5)<25:
        food8 =False
        if food8==False and f8==True:
            score+=1
            f8=False
    if ((((pac_x- 630 )**2)+((pac_y- 25 )**2))**0.5)<25:
        food9 =False
        if food9==False and f9==True:
            score+=1
            f9=False
    if ((((pac_x- 700 )**2)+((pac_y- 25 )**2))**0.5)<25:
        food10 =False
        if food10==False and f10==True:
            score+=1
            f10=False
    if ((((pac_x- 770 )**2)+((pac_y- 25 )**2))**0.5)<25:
        food11 =False
        if food11==False and f11==True:
            score+=1
            f11=False
    if ((((pac_x- 70 )**2)+((pac_y- 172 )**2))**0.5)<25:
        food12 =False
        if food12==False and f12==True:
            score+=1
            f12=False
    if ((((pac_x- 140 )**2)+((pac_y- 172 )**2))**0.5)<25:
        food13 =False
        if food13==False and f13==True:
            score+=1
            f13=False
    if ((((pac_x- 210 )**2)+((pac_y- 172 )**2))**0.5)<25:
        food14 =False
        if food14==False and f14==True:
            score+=1
            f14=False
    if ((((pac_x- 280 )**2)+((pac_y- 172 )**2))**0.5)<25:
        food15 =False
        if food15==False and f15==True:
            score+=1
            f15=False
    if ((((pac_x- 350 )**2)+((pac_y- 172 )**2))**0.5)<25:
        food16 =False
        if food16==False and f16==True:
            score+=1
            f16=False
    if ((((pac_x- 420 )**2)+((pac_y- 172 )**2))**0.5)<25:
        food17 =False
        if food17==False and f17==True:
            score+=1
            f17=False
    if ((((pac_x- 490 )**2)+((pac_y- 172 )**2))**0.5)<25:
        food18 =False
        if food18==False and f18==True:
            score+=1
            f18=False
    if ((((pac_x- 560 )**2)+((pac_y- 172 )**2))**0.5)<25:
        food19 =False
        if food19==False and f19==True:
            score+=1
            f19=False
    if ((((pac_x- 630 )**2)+((pac_y- 172 )**2))**0.5)<25:
        food20 =False
        if food20==False and f20==True:
            score+=1
            f20=False
    if ((((pac_x- 700 )**2)+((pac_y- 172 )**2))**0.5)<25:
        food21 =False
        if food21==False and f21==True:
            score+=1
            f21=False
    if ((((pac_x- 770 )**2)+((pac_y- 172 )**2))**0.5)<25:
        food22 =False
        if food22==False and f22==True:
            score+=1
            f22=False
    if ((((pac_x- 70 )**2)+((pac_y- 328 )**2))**0.5)<25:
        food23 =False
        if food23==False and f23==True:
            score+=1
            f23=False
    if ((((pac_x- 140 )**2)+((pac_y- 328 )**2))**0.5)<25:
        food24 =False
        if food24==False and f24==True:
            score+=1
            f24=False
    if ((((pac_x- 210 )**2)+((pac_y- 328 )**2))**0.5)<25:
        food25 =False
        if food25==False and f25==True:
            score+=1
            f25=False
    if ((((pac_x- 280 )**2)+((pac_y- 328 )**2))**0.5)<25:
        food26 =False
        if food26==False and f26==True:
            score+=1
            f26=False
    if ((((pac_x- 350 )**2)+((pac_y- 328 )**2))**0.5)<25:
        food27 =False
        if food27==False and f27==True:
            score+=1
            f27=False
    if ((((pac_x- 420 )**2)+((pac_y- 328 )**2))**0.5)<25:
        food28 =False
        if food28==False and f28==True:
            score+=1
            f28=False
    if ((((pac_x- 490 )**2)+((pac_y- 328 )**2))**0.5)<25:
        food29 =False
        if food29==False and f29==True:
            score+=1
            f29=False
    if ((((pac_x- 560 )**2)+((pac_y- 328 )**2))**0.5)<25:
        food30 =False
        if food30==False and f30==True:
            score+=1
            f30=False
    if ((((pac_x- 630 )**2)+((pac_y- 328 )**2))**0.5)<25:
        food31 =False
        if food31==False and f31==True:
            score+=1
            f31=False
    if ((((pac_x- 700 )**2)+((pac_y- 328 )**2))**0.5)<25:
        food32 =False
        if food32==False and f32==True:
            score+=1
            f32=False
    if ((((pac_x- 770 )**2)+((pac_y- 328 )**2))**0.5)<25:
        food33 =False
        if food33==False and f33==True:
            score+=1
            f33=False
    if ((((pac_x- 70 )**2)+((pac_y- 475 )**2))**0.5)<25:
        food34 =False
        if food34==False and f34==True:
            score+=1
            f34=False
    if ((((pac_x- 140 )**2)+((pac_y- 475 )**2))**0.5)<25:
        food35 =False
        if food35==False and f35==True:
            score+=1
            f35=False
    if ((((pac_x- 210 )**2)+((pac_y- 475 )**2))**0.5)<25:
        food36 =False
        if food36==False and f36==True:
            score+=1
            f36=False
    if ((((pac_x- 280 )**2)+((pac_y- 475 )**2))**0.5)<25:
        food37 =False
        if food37==False and f37==True:
            score+=1
            f37=False
    if ((((pac_x- 350 )**2)+((pac_y- 475 )**2))**0.5)<25:
        food38 =False
        if food38==False and f38==True:
            score+=1
            f38=False
    if ((((pac_x- 420 )**2)+((pac_y- 475 )**2))**0.5)<25:
        food39 =False
        if food39==False and f39==True:
            score+=1
            f39=False
    if ((((pac_x- 490 )**2)+((pac_y- 475 )**2))**0.5)<25:
        food40 =False
        if food40==False and f40==True:
            score+=1
            f40=False
    if ((((pac_x- 560 )**2)+((pac_y- 475 )**2))**0.5)<25:
        food41 =False
        if food41==False and f41==True:
            score+=1
            f41=False
    if ((((pac_x- 630 )**2)+((pac_y- 475 )**2))**0.5)<25:
        food42 =False
        if food42==False and f42==True:
            score+=1
            f42=False
    if ((((pac_x- 700 )**2)+((pac_y- 475 )**2))**0.5)<25:
        food43 =False
        if food43==False and f43==True:
            score+=1
            f43=False
    if ((((pac_x- 770 )**2)+((pac_y- 475 )**2))**0.5)<25:
        food44 =False
        if food44==False and f44==True:
            score+=1
            f44=False
    if ((((pac_x- 25 )**2)+((pac_y- 70 )**2))**0.5)<25:
        food45 =False
        if food45==False and f45==True:
            score+=1
            f45=False
    if ((((pac_x- 25 )**2)+((pac_y- 140 )**2))**0.5)<25:
        food46 =False
        if food46==False and f46==True:
            score+=1
            f46=False
    if ((((pac_x- 25 )**2)+((pac_y- 210 )**2))**0.5)<25:
        food47 =False
        if food47==False and f47==True:
            score+=1
            f47=False
    if ((((pac_x- 25 )**2)+((pac_y- 280 )**2))**0.5)<25:
        food48 =False
        if food48==False and f48==True:
            score+=1
            f48=False
    if ((((pac_x- 25 )**2)+((pac_y- 350 )**2))**0.5)<25:
        food49 =False
        if food49==False and f49==True:
            score+=1
            f49=False
    if ((((pac_x- 25 )**2)+((pac_y- 420 )**2))**0.5)<25:
        food50 =False
        if food50==False and f50==True:
            score+=1
            f50=False
    if ((((pac_x- 25 )**2)+((pac_y- 490 )**2))**0.5)<25:
        food51 =False
        if food51==False and f51==True:
            score+=1
            f51=False
    if ((((pac_x- 277 )**2)+((pac_y- 70 )**2))**0.5)<25:
        food52 =False
        if food52==False and f52==True:
            score+=1
            f52=False
    if ((((pac_x- 277 )**2)+((pac_y- 140 )**2))**0.5)<25:
        food53 =False
        if food53==False and f53==True:
            score+=1
            f53=False
    if ((((pac_x- 277 )**2)+((pac_y- 210 )**2))**0.5)<25:
        food54 =False
        if food54==False and f54==True:
            score+=1
            f54=False
    if ((((pac_x- 277 )**2)+((pac_y- 280 )**2))**0.5)<25:
        food55 =False
        if food55==False and f55==True:
            score+=1
            f55=False
    if ((((pac_x- 277 )**2)+((pac_y- 350 )**2))**0.5)<25:
        food56 =False
        if food56==False and f56==True:
            score+=1
            f56=False
    if ((((pac_x- 277 )**2)+((pac_y- 420 )**2))**0.5)<25:
        food57 =False
        if food57==False and f57==True:
            score+=1
            f57=False
    if ((((pac_x- 277 )**2)+((pac_y- 490 )**2))**0.5)<25:
        food58 =False
        if food58==False and f58==True:
            score+=1
            f58=False
    if ((((pac_x- 526 )**2)+((pac_y- 70 )**2))**0.5)<25:
        food59 =False
        if food59==False and f59==True:
            score+=1
            f59=False
    if ((((pac_x- 526 )**2)+((pac_y- 140 )**2))**0.5)<25:
        food60 =False
        if food60==False and f60==True:
            score+=1
            f60=False
    if ((((pac_x- 526 )**2)+((pac_y- 210 )**2))**0.5)<25:
        food61 =False
        if food61==False and f61==True:
            score+=1
            f61=False
    if ((((pac_x- 526 )**2)+((pac_y- 280 )**2))**0.5)<25:
        food62 =False
        if food62==False and f62==True:
            score+=1
            f62=False
    if ((((pac_x- 526 )**2)+((pac_y- 350 )**2))**0.5)<25:
        food63 =False
        if food63==False and f63==True:
            score+=1
            f63=False
    if ((((pac_x- 526 )**2)+((pac_y- 420 )**2))**0.5)<25:
        food64 =False
        if food64==False and f64==True:
            score+=1
            f64=False
    if ((((pac_x- 526 )**2)+((pac_y- 490 )**2))**0.5)<25:
        food65 =False
        if food65==False and f65==True:
            score+=1
            f65=False
    if ((((pac_x- 775 )**2)+((pac_y- 70 )**2))**0.5)<25:
        food66 =False
        if food66==False and f66==True:
            score+=1
            f66=False
    if ((((pac_x- 775 )**2)+((pac_y- 140 )**2))**0.5)<25:
        food67 =False
        if food67==False and f67==True:
            score+=1
            f67=False
    if ((((pac_x- 775 )**2)+((pac_y- 210 )**2))**0.5)<25:
        food68 =False
        if food68==False and f68==True:
            score+=1
            f68=False
    if ((((pac_x- 775 )**2)+((pac_y- 280 )**2))**0.5)<25:
        food69 =False
        if food69==False and f69==True:
            score+=1
            f69=False
    if ((((pac_x- 775 )**2)+((pac_y- 350 )**2))**0.5)<25:
        food70 =False
        if food70==False and f70==True:
            score+=1
            f70=False
    if ((((pac_x- 775 )**2)+((pac_y- 420 )**2))**0.5)<25:
        food71 =False
        if food71==False and f71==True:
            score+=1
            f71=False
    if ((((pac_x- 775 )**2)+((pac_y- 490 )**2))**0.5)<25:
        food72 =False
        if food72==False and f72==True:
            score+=1
            f72=False
        
    screen.blit(textsurface,(100,510))
    screen.blit(textsurface2,(10,510))
    
    
    if score==72:
        win=True
    if win==True:
        screen.blit(textsurface4,(240,220))
    
    ###############################################################################################################
    
    pygame.display.flip()

    clock.tick(60)

pygame.quit()
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.8.8)
# Hello from the pygame community. https://www.pygame.org/contribute.html
